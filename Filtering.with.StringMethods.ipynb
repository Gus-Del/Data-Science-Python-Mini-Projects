# %%
import pandas as pd

# %%
laptops = pd.read_csv(r"D:\Data Analytics\Python\laptop_prices.csv", encoding = 'ISO-8859-1')

# %%
pd.set_option('display.max.rows', 5)
laptops
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# 1       13.3                            1440x900
# ...      ...                                 ...
# 1301    15.6                            1366x768
# 1302    15.6                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...

# %%
laptops.info() #gives overview of data
#can filter text columns, object, using strings.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_usd         1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  Price_usd
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg   1473.659
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg    988.834
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg    632.500

# %%
laptops[laptops['Product'].str.contains('Mac')]
#will filter for 'Mac" in product column.
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# ...         ...     ...          ...        ...     ...
# 1210       1228   Apple  MacBook 12"  Ultrabook    12.0
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6
#
#                         ScreenResolution                   Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                               1440x900  Intel Core i5 1.8GHz  8GB
# ...                                  ...                   ...  ...
# 1210  IPS Panel Retina Display 2304x1440   Intel Core M 1.2GHz  8GB
# 1234                            1366x768  Intel Core i5 1.6GHz  4GB
#
#                    Memory                           Gpu     OpSys   Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640     macOS   1.37kg
# ...

# %%
laptops[laptops['Memory'].str.contains('SSD')]
# Out:
#       laptop_ID Company         Product            TypeName  Inches  \
# 0             1   Apple     MacBook Pro           Ultrabook    13.3
# 2             3      HP          250 G6            Notebook    15.6
# ...         ...     ...             ...                 ...     ...
# 1298       1316  Lenovo  Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu  \
# 0             IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                              Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# ...                                          ...                         ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 6500U 2.5GHz
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  Intel Core i7 6500U 2.5GHz
#
#        Ram     Memory                           Gpu       OpSys  Weight  \
# ...

# %%
laptops[~laptops['Memory'].str.contains('SSD')]
#The '~' means it does not contain SSD.
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 1             2   Apple                          Macbook Air  Ultrabook
# 5             6    Acer                             Aspire 3   Notebook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches ScreenResolution                                   Cpu  Ram  \
# 1       13.3         1440x900                  Intel Core i5 1.8GHz  8GB
# 5       15.6         1366x768               AMD A9-Series 9420 3GHz  4GB
# ...      ...              ...                                   ...  ...
# 1301    15.6         1366x768            Intel Core i7 6500U 2.5GHz  6GB
# 1302    15.6         1366x768  Intel Celeron Dual Core N3050 1.6GHz  4GB
#
#                    Memory                     Gpu       OpSys  Weight  \
# ...

# %%
laptops[laptops['Memory'].str.contains('SSD')== False]
#string does not contain SSD.
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 1             2   Apple                          Macbook Air  Ultrabook
# 5             6    Acer                             Aspire 3   Notebook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches ScreenResolution                                   Cpu  Ram  \
# 1       13.3         1440x900                  Intel Core i5 1.8GHz  8GB
# 5       15.6         1366x768               AMD A9-Series 9420 3GHz  4GB
# ...      ...              ...                                   ...  ...
# 1301    15.6         1366x768            Intel Core i7 6500U 2.5GHz  6GB
# 1302    15.6         1366x768  Intel Celeron Dual Core N3050 1.6GHz  4GB
#
#                    Memory                     Gpu       OpSys  Weight  \
# ...

# %%
laptops[(laptops['Memory'].str.contains('SSD') == False) & (laptops['Product'].str.contains('Air'))]
# Out:
#       laptop_ID Company      Product   TypeName  Inches ScreenResolution  \
# 1             2   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 7             8   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 26           27   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 34           35   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6         1366x768
#
#                        Cpu  Ram               Memory                     Gpu  \
# 1     Intel Core i5 1.8GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 7     Intel Core i5 1.8GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 26    Intel Core i5 1.6GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 34    Intel Core i5 1.6GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 1234  Intel Core i5 1.6GHz  4GB  256GB Flash Storage  Intel HD Graphics 6000
#
#          OpSys  Weight  Price_usd
# ...

# %%
laptops[laptops['Memory'].str.startswith('256')]
# Out:
#       laptop_ID Company        Product            TypeName  Inches  \
# 2             3      HP         250 G6            Notebook    15.6
# 4             5   Apple    MacBook Pro           Ultrabook    13.3
# ...         ...     ...            ...                 ...     ...
# 1249       1267    Dell         XPS 13  2 in 1 Convertible    13.3
# 1253       1271  Lenovo  ThinkPad L460            Notebook    14.0
#
#                         ScreenResolution                         Cpu  Ram  \
# 2                      Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 4     IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz  8GB
# ...                                  ...                         ...  ...
# 1249    Quad HD+ / Touchscreen 3200x1800   Intel Core i5 7Y54 1.2GHz  8GB
# 1253         IPS Panel Full HD 1920x1080  Intel Core i5 6200U 2.3GHz  8GB
#
#          Memory                           Gpu       OpSys  Weight  Price_usd
# ...

# %%
laptops[laptops['Memory'].str.endswith('SSD')]
# Out:
#       laptop_ID Company         Product            TypeName  Inches  \
# 0             1   Apple     MacBook Pro           Ultrabook    13.3
# 2             3      HP          250 G6            Notebook    15.6
# ...         ...     ...             ...                 ...     ...
# 1298       1316  Lenovo  Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu  \
# 0             IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                              Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# ...                                          ...                         ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 6500U 2.5GHz
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  Intel Core i7 6500U 2.5GHz
#
#        Ram     Memory                           Gpu       OpSys  Weight  \
# ...

# %%
 laptops[laptops['laptop_ID'].str.contains('1')]
#Gives error bc can only use str with string columns/values.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 laptops[laptops['laptop_ID'].str.contains('1')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
laptops[laptops['Product'].str.match('Mac')]
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# ...         ...     ...          ...        ...     ...
# 1210       1228   Apple  MacBook 12"  Ultrabook    12.0
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6
#
#                         ScreenResolution                   Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                               1440x900  Intel Core i5 1.8GHz  8GB
# ...                                  ...                   ...  ...
# 1210  IPS Panel Retina Display 2304x1440   Intel Core M 1.2GHz  8GB
# 1234                            1366x768  Intel Core i5 1.6GHz  4GB
#
#                    Memory                           Gpu     OpSys   Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640     macOS   1.37kg
# ...

# %%
laptops[laptops['Product'].str.match('Mac.*Air')]
#The .*Air means we  need a Mac but at the end we need Air.
# Out:
#       laptop_ID Company      Product   TypeName  Inches ScreenResolution  \
# 1             2   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 7             8   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 26           27   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 34           35   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6         1366x768
#
#                        Cpu  Ram               Memory                     Gpu  \
# 1     Intel Core i5 1.8GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 7     Intel Core i5 1.8GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 26    Intel Core i5 1.6GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 34    Intel Core i5 1.6GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 1234  Intel Core i5 1.6GHz  4GB  256GB Flash Storage  Intel HD Graphics 6000
#
#          OpSys  Weight  Price_usd
# ...

# %%
#Write a Query to return bakery items that contain the word "Chocolate".
#Column is called product_name. Database is bakery_items. 

bakery_items[bakery_items['product_name'].str.contains('Chocolate')]
