# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
#import numpy as np
#netflix1990_1999=np.logical_and(netflix_df['release_year']>1989, netflix_df['release_year'] < 2000)
#df[(df.val > 0.5) & (df.val2 == 1)]

#netflix1990_1999=netflix_df[(netflix_df['release_year']>1989) & (netflix_df['release_year']<2000)]
#netflix1990_1999

#plt.hist(netflix1990_1999['duration'])
# Out:
# (array([ 1.,  3.,  3., 10., 45., 49., 29., 18., 16., 10.]),
#  array([  1. ,  20.4,  39.8,  59.2,  78.6,  98. , 117.4, 136.8, 156.2,
#         175.6, 195. ]),
#  <BarContainer object of 10 artists>)

# %%
netflix_df[(netflix_df['release_year']>1989) & (netflix_df['release_year']<2000)]
# Out:
#      show_id  ...           genre
# 6         s8  ...          Dramas
# 118     s167  ...          Dramas
# 145     s211  ...        Comedies
# 167     s239  ...        Comedies
# 194     s274  ...          Dramas
# ...      ...  ...             ...
# 4672   s7536  ...          Dramas
# 4689   s7571  ...  Classic Movies
# 4718   s7624  ...          Action
# 4746   s7682  ...          Action
# 4756   s7695  ...          Dramas
#
# [184 rows x 11 columns]

# %%
#Use plt.hist() on your desired column to view the distribution of its values.
#Look at the plot to see where the most frequent count falls and save the duration value as duration.

plt.hist(netflix_df[netflix1990_1999]['duration'])

#not sure if the above is correct. I'd like to know another way of coding this as I'm not #confident in the above.
# Out:
# (array([ 2.,  4.,  9., 31., 44., 31., 16., 13., 13.,  6.]),
#  array([ 28. ,  44.7,  61.4,  78.1,  94.8, 111.5, 128.2, 144.9, 161.6,
#         178.3, 195. ]),
#  <BarContainer object of 10 artists>)

# %%
#I want to make sure that the above graph is the correct graph that represents 1990s movies and #their duration in minutes. 
duration=110

# %%
#A movie is considered short if it is less than 90 minutes. Count the number of short action #movies released in the 1990s and save this integer as short_movie_count.


#Subset a DataFrame is to use square brackets, passing in a condition. For example, if you wanted #to subset a music_df DataFrame for rows where the column genre was "pop", you could use the #following: 
#music_df[music_df["genre"] == "pop"]

#netflix_df[netflix_df['genre']=='Action']

#I wanted to use the code above, but it wouldn't let me save it as something else meaning, #short_actionmovie_count=netflix_df[netflix_df['genre']=='Action']

#import numpy as np

#short_actionmovie_count=np.logical_and(netflix_df['genre']=='Action', netflix_df['duration'] < 90)
#print(short_actionmovie_count)

netflix1990_1999[(netflix1990_1999['duration']<90) & (netflix1990_1999['genre']=='Action')]
# Out:
#      show_id   type  ...                                        description   genre
# 1288   s2039  Movie  ...  Fifteen years after the Second Impact, apathet...  Action
# 1698   s2708  Movie  ...  A pugilist from Shantung struggles to rise to ...  Action
# 2328   s3718  Movie  ...  An officer killed on the job returns to Earth ...  Action
# 2993   s4787  Movie  ...  Air marshal John Cutter must stop notorious te...  Action
# 3297   s5299  Movie  ...  During a visit to the Bronx to help out at his...  Action
# 3806   s6114  Movie  ...  While working at a family friend's business, a...  Action
# 3943   s6330  Movie  ...  Seele orders an all-out attack on NERV, aiming...  Action
#
# [7 rows x 11 columns]

# %%
netflix_df[short_actionmovie_count]
#i'd like to know another way to print this list below. The above doesn't always make sense to me.
# Out:
#      show_id   type  ...                                        description   genre
# 2         s4  Movie  ...  In a postapocalyptic world, rag-doll robots hi...  Action
# 62       s93  Movie  ...  After a musician dies under suspicious circums...  Action
# 71      s105  Movie  ...  Two crooks planning a bank heist wind up abduc...  Action
# 216     s302  Movie  ...  Devastated by the murder of his wife and child...  Action
# 217     s303  Movie  ...  When his future sister-in-law is kidnapped by ...  Action
# ...      ...    ...  ...                                                ...     ...
# 4547   s7331  Movie  ...  Six fearless surfers travel to the north coast...  Action
# 4669   s7530  Movie  ...  At a basketball game, an ex-Special Forces off...  Action
# 4693   s7576  Movie  ...  The getaway driver in a botched robbery puts h...  Action
# 4698   s7588  Movie  ...  Paul Newman proves he's still got prodigious a...  Action
# ...

# %%
short_movie=np.logical_and(netflix_df[short_actionmovie_count]['release_year']>1989, netflix_df[short_actionmovie_count]['release_year']<2000)

print(short_movie)
# Out:
# 2       False
# 62      False
# 71      False
# 216     False
# 217     False
#         ...
# 4547    False
# 4669    False
# 4693    False
# 4698    False
# 4783    False
# Name: release_year, Length: 80, dtype: bool

# %%
netflix_df[short_actionmovie_count][short_movie]
# Out:
#      show_id   type  ...                                        description   genre
# 1288   s2039  Movie  ...  Fifteen years after the Second Impact, apathet...  Action
# 1698   s2708  Movie  ...  A pugilist from Shantung struggles to rise to ...  Action
# 2328   s3718  Movie  ...  An officer killed on the job returns to Earth ...  Action
# 2993   s4787  Movie  ...  Air marshal John Cutter must stop notorious te...  Action
# 3297   s5299  Movie  ...  During a visit to the Bronx to help out at his...  Action
# 3806   s6114  Movie  ...  While working at a family friend's business, a...  Action
# 3943   s6330  Movie  ...  Seele orders an all-out attack on NERV, aiming...  Action
#
# [7 rows x 11 columns]

# %%
short_movie_count= 7
#I figured out that my years should have been greater than 1989< and less than 2000>

# %%
# !pip install pandoc
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/127.6 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/127.6 kB 640.0 kB/s eta 0:00:01
#    ------------ -------------------------- 41.0/127.6 kB 487.6 kB/s eta 0:00:01
#    ------------------ -------------------- 61.4/127.6 kB 544.7 kB/s eta 0:00:01
#    ------------------ -------------------- 61.4/127.6 kB 544.7 kB/s eta 0:00:01
#    ------------------ -------------------- 61.4/127.6 kB 544.7 kB/s eta 0:00:01
#    ---------------------------- ---------- 92.2/127.6 kB 290.5 kB/s eta 0:00:01
#    ------------------------------------ - 122.9/127.6 kB 359.9 kB/s eta 0:00:01
#    -------------------------------------- 127.6/127.6 kB 341.2 kB/s eta 0:00:00
# ...
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33286 sha256=b7cf634a9efe266dddf97bb10f1833a6fc2cd9363f0ae737297b2486bc49d74d
# ...
